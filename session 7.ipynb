# %% [markdown]
# # Session 7

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(0, 1, 0.01)
y = np.exp(x)

# %%
plt.plot(x,y)
plt.xlabel('Time [milliseconds]')
plt.ylabel('Awesomeness')
plt.savefig("s7-plot.pdf")
